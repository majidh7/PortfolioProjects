# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('titles.csv' , index_col = 'id')
data.head()
# Out:
#                        title   type  \
# id
# tm155702    The Wizard of Oz  MOVIE
# tm83648         Citizen Kane  MOVIE
# tm77588           Casablanca  MOVIE
# tm82363        The Big Sleep  MOVIE
# tm84701   The Maltese Falcon  MOVIE
#
#                                                 description  release_year  \
# id
# tm155702  Young Dorothy finds herself in a magical world...          1939
# tm83648   Newspaper magnate, Charles Foster Kane is take...          1941
# tm77588   In Casablanca, Morocco in December 1941, a cyn...          1942
# tm82363   Private Investigator Philip Marlowe is hired b...          1946
# tm84701   A private detective takes on a case that invol...          1941
#
#          age_certification  runtime                            genres  \
# id
# tm155702                 G      102             ['fantasy', 'family']
# tm83648                 PG      119                         ['drama']
# tm77588                 PG      102       ['drama', 'romance', 'war']
# ...

# %%
data.rename({'tmdb_popularity' : 'imdb_populirity'} , axis = 1 , inplace = True)

# %%
data.drop('tmdb_score' , axis = 1 , inplace = True)

# %%
data.head()
# Out:
#                        title   type  \
# id
# tm155702    The Wizard of Oz  MOVIE
# tm83648         Citizen Kane  MOVIE
# tm77588           Casablanca  MOVIE
# tm82363        The Big Sleep  MOVIE
# tm84701   The Maltese Falcon  MOVIE
#
#                                                 description  release_year  \
# id
# tm155702  Young Dorothy finds herself in a magical world...          1939
# tm83648   Newspaper magnate, Charles Foster Kane is take...          1941
# tm77588   In Casablanca, Morocco in December 1941, a cyn...          1942
# tm82363   Private Investigator Philip Marlowe is hired b...          1946
# tm84701   A private detective takes on a case that invol...          1941
#
#          age_certification  runtime                            genres  \
# id
# tm155702                 G      102             ['fantasy', 'family']
# tm83648                 PG      119                         ['drama']
# tm77588                 PG      102       ['drama', 'romance', 'war']
# ...

# %%
data.isnull().sum()
# Out:
# title                      0
# type                       0
# description               12
# release_year               0
# age_certification       1208
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 2538
# imdb_id                  326
# imdb_score               372
# imdb_votes               383
# imdb_populirity           33
# dtype: int64

# %%
data['age_certification'].fillna('UNK' , inplace = True)

# %%
data['seasons'].fillna(0 , inplace = True)

# %%
data['imdb_id'].fillna(0 , inplace = True)

# %%
data['imdb_score'].fillna(0 , inplace = True)

# %%
data['imdb_votes'].fillna(0 , inplace = True)

# %%
data['imdb_populirity'].fillna(0 , inplace = True)

# %%
data.dropna(axis = 0 , inplace = True)

# %%
data
# Out:
#                                                     title   type  \
# id
# tm155702                                 The Wizard of Oz  MOVIE
# tm83648                                      Citizen Kane  MOVIE
# tm77588                                        Casablanca  MOVIE
# tm82363                                     The Big Sleep  MOVIE
# tm84701                                The Maltese Falcon  MOVIE
# ...                                                   ...    ...
# tm1082718  Romeo Santos: Utopia Live from MetLife Stadium  MOVIE
# tm1067128                                       Algo Azul  MOVIE
# tm1121489                        Entre Nos: What She Said  MOVIE
# tm1121486                        Entre Nos: The Winners 2  MOVIE
# tm989132                              The Infamous Future  MOVIE
#
#                                                  description  release_year  \
# id
# tm155702   Young Dorothy finds herself in a magical world...          1939
# ...

# %%
data.isnull().sum()
# Out:
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# imdb_populirity         0
# dtype: int64

# %%
data['release_year'].sort_values(ascending = False)
# Out:
# id
# ts213237     2022
# tm1114713    2022
# ts331418     2022
# ts341605     2022
# tm1128929    2022
#              ...
# tm72458      1904
# tm34570      1903
# tm1889       1902
# tm127045     1902
# tm54582      1901
# Name: release_year, Length: 3282, dtype: int64

# %%
data['runtime'].sort_values(ascending = False)
# Out:
# id
# tm26941     255
# tm364104    251
# tm893885    242
# tm156463    233
# tm36548     232
#            ...
# tm29593       3
# ts87179       3
# tm34570       2
# tm54582       2
# tm1889        1
# Name: runtime, Length: 3282, dtype: int64

# %%
sns.kdeplot(data['runtime'] , shade = True)
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='Density'>

# %%
q = data['runtime'].quantile(0.15)
data1 = data[data['runtime'] > q ]

# %%
sns.kdeplot(data1['runtime'] , shade = True)
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='Density'>

# %%
data['seasons'].sort_values(ascending = False)
# Out:
# id
# ts22243     52.0
# ts20371     31.0
# ts36446     28.0
# ts13206     26.0
# ts21792     25.0
#             ...
# tm68758      0.0
# tm33947      0.0
# tm92889      0.0
# tm37483      0.0
# tm989132     0.0
# Name: seasons, Length: 3282, dtype: float64

# %%
data.duplicated().sum()
# Out:
# 0
